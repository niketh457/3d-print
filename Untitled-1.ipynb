# %%
import fullcontrol as fc
steps = []

steps.append(fc.Point(x=0, y=0, z=0))
steps.append(fc.Point(x=0, y=1, z=0))
steps.append(fc.Point(x=1, y=0, z=0))
steps.append(fc.Point(x=0, y=0, z=1))
steps.append(fc.Point(x=1, y=0, z=1))
steps.append(fc.Point(x=1, y=1, z=0))
steps.append(fc.Point(x=0, y=1, z=1))
steps.append(fc.Point(x=1, y=1, z=1))

# %%
fc.transform(steps, 'plot')
